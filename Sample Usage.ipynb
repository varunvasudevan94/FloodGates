# %% [markdown]
# # Example

# %%
import floodgate

filename = 'mygame.pgn'

# %%
# %matplotlib notebook
floodgate.get_animation_from_file(filename)
# Out:
# <img src="data:image/png;base64,..." width="640">
